# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 monthly_sales = df.groupby(["year", "month"])["sales"].sum().reset_index()
#       2 monthly_sales["time_index"] = range(len(monthly_sales))
#       4 monthly_sales["date"] = pd.to_datetime(
#       5     monthly_sales["year"].astype(str) + "-" +
#       6     monthly_sales["month"].astype(str) + "-01"
#       7 )
#
# NameError: name 'df' is not defined
